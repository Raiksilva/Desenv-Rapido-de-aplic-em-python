# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount ('/content/drive', True)
# Out:
# Mounted at /content/drive

# %%
arquivo = '/content/drive/MyDrive/titanic.csv'
dataset = pd.read_csv(arquivo, sep=',', header=0)

print('Base carregada com sucesso')
# Out:
# Base carregada com sucesso

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# ...
#      | 22.6 MB 21.9 MB/s 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 39.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 14.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 55.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 98.2 MB/s eta 0:00:00
# ...
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=357350 sha256=1f0c41bbdebfcb4e00e67d4bdc2c35ca1449066e1c43dc1a74e0bd302b61dbd1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9srerav3/wheels/07/29/61/f533cc7cbd0a97efb2d1b94d3254a3e859a949367ba842577b
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=b54356227954962cde574df2fb7578163858740f31ab650b4ae4a4787bcda9dd
# ...

# %%
import pandas_profiling

print('panda importado com sucesso!')
# Out:
# panda importado com sucesso!
# <ipython-input-16-726918c5adb7>:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
profile = pandas_profiling.ProfileReport(dataset)
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
profile.to_file("/content/drive/MyDrive/DevRap.hmtl")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:360: UserWarning: Extension .hmtl not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
