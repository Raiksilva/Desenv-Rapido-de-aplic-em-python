# %% [markdown]
# # Aula 01- Desenvolvimente Rápido de aplicações em python

# %%
import pandas as pd

# %%
dict_test = {
    "Nome": ["Kelvin", "Maria", "José", "Carlos", "google", "Sebastião", "Flavia", "Carla", "Joana", "bolinha"],
    "Gênero":["Masculino", "Feminino", "Masculino", "Masculino", "Masculino", "Masculino", "Fem", "Fem", "Fem", "Masc"],
    "Idade": [12, 20, 25, 32, 52, 15, 89, 45, 21, 70],
    "UF": ["PE", "DF", "BA", "SP", "RJ", "BH", "AC", "MN", "PB", "RN"]
    }

# %%
df = pd.DataFrame(dict_test)

# %%
df.head()
# Out:
#      Nome     Gênero  Idade  UF
# 0  Kelvin  Masculino     12  PE
# 1   Maria   Feminino     20  DF
# 2    José  Masculino     25  BA
# 3  Carlos  Masculino     32  SP
# 4  google  Masculino     52  RJ

# %%
df.head(11)
# Out:
#         Nome     Gênero  Idade  UF
# 0     Kelvin  Masculino     12  PE
# 1      Maria   Feminino     20  DF
# 2       José  Masculino     25  BA
# 3     Carlos  Masculino     32  SP
# 4     google  Masculino     52  RJ
# 5  Sebastião  Masculino     15  BH
# 6     Flavia        Fem     89  AC
# 7      Carla        Fem     45  MN
# 8      Joana        Fem     21  PB
# 9    bolinha       Masc     70  RN

# %%
df.tail(15)
# Out:
#         Nome     Gênero  Idade  UF
# 0     Kelvin  Masculino     12  PE
# 1      Maria   Feminino     20  DF
# 2       José  Masculino     25  BA
# 3     Carlos  Masculino     32  SP
# 4     google  Masculino     52  RJ
# 5  Sebastião  Masculino     15  BH
# 6     Flavia        Fem     89  AC
# 7      Carla        Fem     45  MN
# 8      Joana        Fem     21  PB
# 9    bolinha       Masc     70  RN

# %%
df.describe()
# Out:
#            Idade
# count  10.000000
# mean   38.100000
# std    25.588409
# min    12.000000
# 25%    20.250000
# 50%    28.500000
# 75%    50.250000
# max    89.000000

# %%
df.columns
# Out:
# Index(['Nome', 'Gênero', 'Idade', 'UF'], dtype='object')

# %%
df.count
# Out:
# <bound method DataFrame.count of         Nome     Gênero  Idade  UF
# 0     Kelvin  Masculino     12  PE
# 1      Maria   Feminino     20  DF
# 2       José  Masculino     25  BA
# 3     Carlos  Masculino     32  SP
# 4     google  Masculino     52  RJ
# 5  Sebastião  Masculino     15  BH
# 6     Flavia        Fem     89  AC
# 7      Carla        Fem     45  MN
# 8      Joana        Fem     21  PB
# 9    bolinha       Masc     70  RN>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    10 non-null     object
#  1   Gênero  10 non-null     object
#  2   Idade   10 non-null     int64
#  3   UF      10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes

# %%
df.shape
# Out:
# (10, 4)

# %%
df.sample(7)
# Out:
#       Nome     Gênero  Idade  UF
# 7    Carla        Fem     45  MN
# 3   Carlos  Masculino     32  SP
# 8    Joana        Fem     21  PB
# 6   Flavia        Fem     89  AC
# 0   Kelvin  Masculino     12  PE
# 4   google  Masculino     52  RJ
# 9  bolinha       Masc     70  RN
